# %% [markdown]
# ### Introduction

# %% [markdown]
# This dataset explores patterns of time-wasting behavior on social media platforms across various users. It includes information on user demographics, usage habits, video engagement, and behavioral traits related to social media consumption. The primary objective is to analyze the factors that influence time spent on social media, assess its impact on productivity, and examine the roles of self-control and addiction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings                     # to ignore warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r""C:\Users\Sayali\OneDrive\Desktop\Dataset\Time-Wasters on Social Media.csv") # import file

# %%
df.head(5)
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# ...

# %%
pd.set_option('display.max_columns',31) # used to see maximum columns

# %%
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  Total Time Spent  \
# 0       Engineer        Rural  Instagram                80
# 1         Artist        Urban  Instagram               228
# 2       Engineer        Rural   Facebook                30
# 3  Waiting staff        Rural    YouTube               101
# 4        Manager        Urban     TikTok               136
#
#    Number of Sessions  Video ID Video Category  Video Length  Engagement  \
# 0                  17      4229         Pranks            24        7867
# ...

# %%
df.shape
# Out:
# (1000, 31)

# %%
df.isnull().sum()
# Out:
# UserID                      0
# Age                         0
# Gender                      0
# Location                    0
# Income                      0
# Debt                        0
# Owns Property               0
# Profession                  0
# Demographics                0
# Platform                    0
# Total Time Spent            0
# Number of Sessions          0
# Video ID                    0
# Video Category              0
# Video Length                0
# Engagement                  0
# Importance Score            0
# Time Spent On Video         0
# Number of Videos Watched    0
# Scroll Rate                 0
# Frequency                   0
# ProductivityLoss            0
# Satisfaction                0
# Watch Reason                0
# DeviceType                  0
# OS                          0
# Watch Time                  0
# Self Control                0
# Addiction Level             0
# CurrentActivity             0
# ConnectionType              0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# UserID                      1000
# Age                           47
# Gender                         3
# Location                      10
# Income                       996
# Debt                           2
# Owns Property                  2
# Profession                     9
# Demographics                   2
# Platform                       4
# Total Time Spent             278
# Number of Sessions            19
# Video ID                     947
# Video Category                 9
# Video Length                  29
# Engagement                   953
# Importance Score               9
# Time Spent On Video           29
# Number of Videos Watched      49
# Scroll Rate                   99
# Frequency                      4
# ProductivityLoss               9
# Satisfaction                   9
# Watch Reason                   4
# DeviceType                     3
# OS                             4
# Watch Time                    16
# Self Control                   8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %%
# Dropping column which we dont need in our analysis

# %%
df.drop(columns='Video ID',inplace=True)

# %%
df.drop(columns='UserID',inplace=True) # already we have indexing that's why user id we dont need

# %%
df.drop(columns=['Demographics','Number of Sessions','Time Spent On Video','Video Length','Number of Videos Watched','ProductivityLoss','Self Control','DeviceType','OS'],inplace=True)

# %%
# we are going to Add column like age group using "age"

# %%
a = []
for i in df['Age']:
  if i >=18 and i<=25:
    a.append('Young Adults')
  elif i>25 and i<=45:
    a.append('Mid Career')
  elif i>45 and i<=64:
    a.append('Old Or Pre-retirement')
  else:
    a.append(False)

# %%
df['Age Group']= a

# %%
df.head()
# Out:
#    Age  Gender       Location  Income   Debt  Owns Property     Profession  \
# 0   56    Male       Pakistan   82812   True           True       Engineer
# 1   46  Female         Mexico   27999  False           True         Artist
# 2   32  Female  United States   42436  False           True       Engineer
# 3   60    Male         Barzil   62963   True          False  Waiting staff
# 4   25    Male       Pakistan   22096  False           True        Manager
#
#     Platform  Total Time Spent Video Category  Engagement  Importance Score  \
# 0  Instagram                80         Pranks        7867                 5
# 1  Instagram               228         Pranks        5944                 6
# 2   Facebook                30          Vlogs        8674                 3
# 3    YouTube               101          Vlogs        2477                 2
# 4     TikTok               136         Gaming        3093                 7
#
# ...

# %%
df.describe().round()
# Out:
#           Age   Income  Total Time Spent  Engagement  Importance Score  \
# count  1000.0   1000.0            1000.0      1000.0            1000.0
# mean     41.0  59524.0             151.0      4997.0               5.0
# std      13.0  23736.0              84.0      2910.0               3.0
# min      18.0  20138.0              10.0        15.0               1.0
# 25%      29.0  38675.0              78.0      2416.0               3.0
# 50%      42.0  58805.0             152.0      5016.0               5.0
# 75%      52.0  79792.0             223.0      7540.0               7.0
# max      64.0  99676.0             298.0      9982.0               9.0
#
#        Scroll Rate  Satisfaction  Addiction Level
# count       1000.0        1000.0           1000.0
# mean          50.0           5.0              3.0
# std           29.0           2.0              2.0
# min            1.0           1.0              0.0
# 25%           23.0           4.0              2.0
# ...

# %% [markdown]
# Most people in this data are around 41 years old and spend about 2.5 hours daily on social media.
# The scrolling speed is high, which shows many people scroll without thinking.
# The addiction level is medium, but some users are highly addicted.
# This means social media apps should help users control their screen time and use it more carefully.

# %% [markdown]
# #### UNIVARIATE ANALYSIS

# %%
sns.countplot(data=df,x='Age Group',order=df['Age Group'].value_counts().index,palette='muted')
plt.title('Age Group Distribution and Summary')
plt.tight_layout()
plt.show()

# %% [markdown]
# Seems that the people of "Mid Career" and "Old or pre retirement" spends more time on social media

# %% [markdown]
# ### AVERAGE ADDICTION LEVEL BY GENDER WISE

# %%
sns.countplot(data =df,x = 'Gender',palette='muted')
plt.title('Distinguish According to Gender')
# Out:
# Text(0.5, 1.0, 'Distinguish According to Gender')

# %% [markdown]
# According to Gender , "Male" shows most interest in social media

# %% [markdown]
# ### USAGE OF SOCIAL MEDIA BY PROFESSION

# %%
fig = plt.figure(figsize = (8,5))
sns.countplot(data =df,x ='Location',palette='colorblind')
plt.xticks(rotation =55)
plt.ylabel('Number of User')
plt.xlabel('County')
plt.show()

# %% [markdown]
# The people of India spends more time on social media while the people of Germany spends less

# %%
sns.countplot(data = df, x = 'Profession',palette='muted')
plt.xticks(rotation = 70)
plt.ylabel('Number of User')
plt.show()

# %% [markdown]
# Students and Labour/Worker are more active than other on social media. , teachers are less active

# %% [markdown]
# ### ADDICTION LEVEL ON SOCIAL MEDIA

# %%
counts=df['Addiction Level'].value_counts().reset_index()
counts
# Out:
#    Addiction Level  count
# 0                2    248
# 1                5    228
# 2                0    180
# 3                3    159
# 4                1     60
# 5                7     55
# 6                4     36
# 7                6     34

# %% [markdown]
# #### ADDICTION LEVEL ON SOCIAL MEDIA¶
# The Addiction Level from 0 to 7 in your dataset represents the intensity of social media usage
# - Level 0: No or very little use of social media.
# - Level 1: Very low use or dependence.
# - Level 2: Mild use, but not excessive.
# - Level 3: Moderate use, part of the daily routine.
# - Level 4: Significant use, affecting time management.
# - Level 5: High use, impacting other areas of life.
# - Level 6: Very high use, possibly neglecting responsibilities.
# - Level 7: Extreme use, with a strong negative impact.

# %%
#See addiction level of social media in %
plt.figure(figsize=(10,6))
plt.pie(counts['count'],labels=counts['Addiction Level'],autopct="%1.2f%%")
plt.title('ADDICTION LEVEL OF SOCIAL MEDIA')
plt.show()

# %% [markdown]
# ### AVERAGE ADDICTION LEVEL BY AGE GROUP

# %%
# the total Addiction Level
plt.figure(figsize=(8,6))
sns.barplot(data=df, x='Age Group', y='Addiction Level', palette='colorblind')
plt.title("Average Addiction Level by Age Group")
plt.ylabel("Avg Addiction Level")
plt.xlabel("Age Group")
plt.show()

# %% [markdown]
# ### TOTAL TIME SPENT ON SOCIAL MEDIA PLATFORMS

# %%
most_used_platform=df.groupby('Platform')['Total Time Spent'].sum().reset_index()
most_used_platform
# Out:
#     Platform  Total Time Spent
# 0   Facebook             34295
# 1  Instagram             37609
# 2     TikTok             41297
# 3    YouTube             38205

# %%
plt.figure(figsize=(10,6))
plt.pie(most_used_platform['Total Time Spent'],labels=most_used_platform['Platform'],autopct='%1.2f%%')
plt.title('TOTAL TIME SPENT ON SOCIAL MEDIA PLATFORMS')
plt.show()

# %% [markdown]
# TikTok is the most used social media app among them , Instagram and Youtube are nearly equally used.
# The usage of facebook is slightly low as TikTok and Instagram comes in Picture.

# %% [markdown]
# ### WATCHING TIME OF SOCIAL MEDIA

# %%
watch_time_dist=df['Watch Time'].value_counts()
plt.figure(figsize=(12,6))
watch_time_dist.plot(kind='bar',color='#FF4858',title='Distribution of video watch time across different times of day',ylabel='counts');
plt.ylabel('Number of User')
# Out:
# Text(0, 0.5, 'Number of User')

# %% [markdown]
# The data shows that the afternoon 2:00 PM to 5:00 PM and evening 8:00 PM to 11:30 PM are the most active periods for viewership.
# Mornings and early afternoons have relatively low engagement

# %% [markdown]
# ### WATCHING TIME FREQUENCY

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = df['Frequency'])
plt.ylabel('Number of User')
# Out:
# Text(0, 0.5, 'Number of User')

# %%
platform_freq = pd.crosstab(df['Platform'], df['Frequency'])
sns.heatmap(platform_freq, annot=True, cmap='YlGnBu')
plt.title("Platform Usage vs Frequency of Use")
plt.show()

# %% [markdown]
# ### POPULAR VIDEOS BY CATEGORY

# %%
plt.pie(df['Video Category'].value_counts() , labels = df['Video Category']
        .value_counts().index , autopct= '%0.1f%%' )
plt.title('MOST POPULAR VIDEO CATEGORIES')
plt.show()

# %% [markdown]
# ### PLATFORM INCOME

# %%
most_pay_platform=df.groupby('Platform')['Income'].sum().reset_index()
most_pay_platform
# Out:
#     Platform    Income
# 0   Facebook  13170366
# 1  Instagram  15012716
# 2     TikTok  16289461
# 3    YouTube  15051670

# %%
plt.figure(figsize=(10,6))
plt.bar(most_pay_platform['Platform'],most_pay_platform['Income'])
plt.title('Highest Payble Platform')
plt.xlabel('Platform')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# ### WATCHING REASON OF SOCIAL MEDIA

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Watch Reason', order=df['Watch Reason'].value_counts().index, palette='muted')
plt.title("Distribution of Watch Reasons")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 🛍️ For Retail Businesses:
# Insight: Young adults (18–24) spend the most time on Instagram and Tiktok during evening hours.
#
# Recommendation: Schedule flash sales or Instagram Stories ads between 6–9 PM to maximize engagement.
#
# 📱 For Mobile App Startups:
# Insight: Users spending 3+ hours daily on social media report higher app churn.
#
# Recommendation: Use screen-time APIs or offer break reminders within your app to promote healthier usage and boost retention.
#
# 🎓 For Educational Institutions:
# Insight: Students active on TikTok during study hours (12 PM – 6 PM)
#
# Recommendation: Run awareness campaigns on social platforms during those times or gamify focus hours with app-based rewards.
#
# 💼 For HR & Workplace Productivity Tools:
# Insight: Employees aged 25–34 are most active on LinkedIn but also spend significant time on Facebook during working hours.
#
# Recommendation: Offer digital wellness workshops and implement soft social media time tracking during work hours.
#
# 📊 For Marketing Agencies:
#
# Insight: Content type preferences (e.g., memes, reels, educational posts) vary by age group and platform.
#
# Recommendation: Personalize campaign content: use reels for Gen Z on Instagram, infographics for millennials on LinkedIn.

# %% [markdown]
# ### INSIGHTS AND RECCOMENDATION

# %% [markdown]
# 1. 🎓 For Educational Institutes / EdTech Apps
# Insight: Young Adults (18–25) show high addiction levels (Level 4–7).
#
# Recommendation:
#
# Create awareness modules about time management.
#
# Introduce study rewards for reduced social media usage.
#
# Promote focused learning apps using YouTube ads — as that’s where this group likely wastes time.
#
# 2. 🧠 For Health & Wellness Startups
# Insight: Addiction Levels 6–7 correlate with productivity loss (even though you dropped it, it could be merged back if needed).
#
# Recommendation:
#
# Offer digital detox programs or alerts when usage exceeds healthy levels.
#
# Market mindfulness apps directly to users in the 25–45 range with moderate addiction.
#
# 3. 🧑‍💼 For HR and Corporate Productivity Tools
# Insight: Adults (25–45) also show high social media usage, especially during working hours.
#
# Recommendation:
#
# Suggest employers use analytics dashboards to identify usage patterns.
#
# Recommend team challenges: e.g., "Screen-Free Work Hours".
#
# 4. 🛍️ For E-commerce Brands / Social Advertisers
# Insight: Platforms like Instagram, Facebook, and YouTube likely dominate the usage (add platform-specific analysis).
#
# Recommendation:
#
# Use “scroll-stop” ads with catchy content targeted at Young Adults.
#
# Schedule marketing posts during peak addiction hours (evenings, weekends).
#
# 5. 📱 For App Developers or Product Managers
# Insight: High addiction levels are common across user age groups.
#
# Recommendation:
#
# Build features like “Time Spent This Week” summaries.
#
# Add optional reminders to close the app after prolonged use.
